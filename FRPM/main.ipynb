# %%
import yfinance as yf

prices = yf.download("AAPL", start="2020-01-01", end="2026-01-01", progress=False) ['Close']

# %%
# Out:
# Ticker            AAPL
# Date
# 2020-01-02   72.333878
# 2020-01-03   71.630669
# 2020-01-06   72.201416
# 2020-01-07   71.861839
# 2020-01-08   73.017838
# ...                ...
# 2025-12-24  273.302216
# 2025-12-26  272.892975
# 2025-12-29  273.252350
# 2025-12-30  272.573578
# 2025-12-31  271.355835
#
# [1508 rows x 1 columns]
