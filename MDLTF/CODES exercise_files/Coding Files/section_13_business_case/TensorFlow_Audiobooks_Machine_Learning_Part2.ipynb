# %% [markdown]
# # Practical example. Audiobooks

# %% [markdown]
# ## Problem
#
# You are given data from an Audiobook app. Logically, it relates only to the audio versions of books. Each customer in the database has made a purchase at least once, that's why he/she is in the database. We want to create a machine learning algorithm based on our available data that can predict if a customer will buy again from the Audiobook company.
#
# The main idea is that if a customer has a low probability of coming back, there is no reason to spend any money on advertizing to him/her. If we can focus our efforts ONLY on customers that are likely to convert again, we can make great savings. Moreover, this model can identify the most important metrics for a customer to come back again. Identifying new customers creates value and growth opportunities.
#
# You have a .csv summarizing the data. There are several variables: Customer ID, Book length in mins_avg (average of all purchases), Book length in minutes_sum (sum of all purchases), Price Paid_avg (average of all purchases), Price paid_sum (sum of all purchases), Review (a Boolean variable), Review (out of 10), Total minutes listened, Completion (from 0 to 1), Support requests (number), and Last visited minus purchase date (in days).
#
# So these are the inputs (excluding customer ID, as it is completely arbitrary. It's more like a name, than a number).
#
# The targets are a Boolean variable (so 0, or 1). We are taking a period of 2 years in our inputs, and the next 6 months as targets. So, in fact, we are predicting if: based on the last 2 years of activity and engagement, a customer will convert in the next 6 months. 6 months sounds like a reasonable time. If they don't convert after 6 months, chances are they've gone to a competitor or didn't like the Audiobook way of digesting information.
#
# The task is simple: create a machine learning algorithm, which is able to predict if a customer will buy again.
#
# This is a classification problem with two classes: won't buy and will buy, represented by 0s and 1s.
#
# Good luck!

# %% [markdown]
# ## Create the machine learning algorithm

# %% [markdown]
# ### Import the relevant libraries

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ### Data

# %%
npz = np.load('Audiobooks_data_train.npz')

train_inputs = npz['inputs'].astype(np.float)
train_targets = npz['targets'].astype(np.int)

npz = np.load('Audiobooks_data_validation.npz')
validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

npz = np.load('Audiobooks_data_test.npz')
test_inputs, test_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# %% [markdown]
# ### Model
# Outline, optimizers, loss, early stopping and training

# %%
input_size = 10
output_size = 2
hidden_layer_size = 50

model = tf.keras.Sequential([
                            tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
                            tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
                            tf.keras.layers.Dense(output_size, activation='softmax')   
                            ])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

batch_size = 100

max_epochs = 100

model.fit(train_inputs,
         train_targets,
         batch_size = batch_size,
         epochs = max_epochs,
         validation_data=(validation_inputs, validation_targets),
         verbose=2)
# Out:
# Train on 3579 samples, validate on 447 samples
# Epoch 1/100
# 3579/3579 - 0s - loss: 0.5370 - accuracy: 0.8122 - val_loss: 0.4299 - val_accuracy: 0.8613
# Epoch 2/100
# 3579/3579 - 0s - loss: 0.3729 - accuracy: 0.8737 - val_loss: 0.3355 - val_accuracy: 0.8658
# Epoch 3/100
# 3579/3579 - 0s - loss: 0.3197 - accuracy: 0.8826 - val_loss: 0.3031 - val_accuracy: 0.8747
# Epoch 4/100
# 3579/3579 - 0s - loss: 0.2967 - accuracy: 0.8885 - val_loss: 0.2866 - val_accuracy: 0.8859
# Epoch 5/100
# 3579/3579 - 0s - loss: 0.2837 - accuracy: 0.8902 - val_loss: 0.2735 - val_accuracy: 0.9016
# Epoch 6/100
# 3579/3579 - 0s - loss: 0.2737 - accuracy: 0.8961 - val_loss: 0.2736 - val_accuracy: 0.8926
# Epoch 7/100
# 3579/3579 - 0s - loss: 0.2637 - accuracy: 0.8980 - val_loss: 0.2614 - val_accuracy: 0.9038
# Epoch 8/100
# 3579/3579 - 0s - loss: 0.2587 - accuracy: 0.9025 - val_loss: 0.2638 - val_accuracy: 0.9060
# Epoch 9/100
# 3579/3579 - 0s - loss: 0.2557 - accuracy: 0.9019 - val_loss: 0.2545 - val_accuracy: 0.9060
# Epoch 10/100
# 3579/3579 - 0s - loss: 0.2489 - accuracy: 0.9028 - val_loss: 0.2482 - val_accuracy: 0.9060
# Epoch 11/100
# 3579/3579 - 0s - loss: 0.2474 - accuracy: 0.9050 - val_loss: 0.2511 - val_accuracy: 0.9060
# Epoch 12/100
# 3579/3579 - 0s - loss: 0.2452 - accuracy: 0.9064 - val_loss: 0.2424 - val_accuracy: 0.9105
# Epoch 13/100
# 3579/3579 - 0s - loss: 0.2412 - accuracy: 0.9078 - val_loss: 0.2436 - val_accuracy: 0.9083
# Epoch 14/100
# 3579/3579 - 0s - loss: 0.2401 - accuracy: 0.9075 - val_loss: 0.2405 - val_accuracy: 0.9105
# Epoch 15/100
# 3579/3579 - 0s - loss: 0.2371 - accuracy: 0.9098 - val_loss: 0.2393 - val_accuracy: 0.9105
# Epoch 16/100
# 3579/3579 - 0s - loss: 0.2376 - accuracy: 0.9128 - val_loss: 0.2405 - val_accuracy: 0.9016
# Epoch 17/100
# 3579/3579 - 0s - loss: 0.2346 - accuracy: 0.9117 - val_loss: 0.2378 - val_accuracy: 0.9038
# Epoch 18/100
# 3579/3579 - 0s - loss: 0.2340 - accuracy: 0.9117 - val_loss: 0.2378 - val_accuracy: 0.9105
# Epoch 19/100
# 3579/3579 - 0s - loss: 0.2342 - accuracy: 0.9125 - val_loss: 0.2348 - val_accuracy: 0.9150
# Epoch 20/100
# 3579/3579 - 0s - loss: 0.2308 - accuracy: 0.9131 - val_loss: 0.2323 - val_accuracy: 0.9195
# Epoch 21/100
# 3579/3579 - 0s - loss: 0.2298 - accuracy: 0.9123 - val_loss: 0.2369 - val_accuracy: 0.9128
# Epoch 22/100
# 3579/3579 - 0s - loss: 0.2272 - accuracy: 0.9145 - val_loss: 0.2389 - val_accuracy: 0.9083
# Epoch 23/100
# 3579/3579 - 0s - loss: 0.2278 - accuracy: 0.9148 - val_loss: 0.2363 - val_accuracy: 0.9105
# Epoch 24/100
# 3579/3579 - 0s - loss: 0.2255 - accuracy: 0.9148 - val_loss: 0.2350 - val_accuracy: 0.9128
# Epoch 25/100
# 3579/3579 - 0s - loss: 0.2244 - accuracy: 0.9148 - val_loss: 0.2391 - val_accuracy: 0.9128
# Epoch 26/100
# 3579/3579 - 0s - loss: 0.2250 - accuracy: 0.9162 - val_loss: 0.2348 - val_accuracy: 0.9128
# Epoch 27/100
# 3579/3579 - 0s - loss: 0.2240 - accuracy: 0.9156 - val_loss: 0.2307 - val_accuracy: 0.9195
# Epoch 28/100
# 3579/3579 - 0s - loss: 0.2252 - accuracy: 0.9162 - val_loss: 0.2292 - val_accuracy: 0.9150
# Epoch 29/100
# 3579/3579 - 0s - loss: 0.2273 - accuracy: 0.9137 - val_loss: 0.2301 - val_accuracy: 0.9128
# Epoch 30/100
# 3579/3579 - 0s - loss: 0.2235 - accuracy: 0.9156 - val_loss: 0.2272 - val_accuracy: 0.9172
# Epoch 31/100
# 3579/3579 - 0s - loss: 0.2252 - accuracy: 0.9151 - val_loss: 0.2322 - val_accuracy: 0.9128
# Epoch 32/100
# 3579/3579 - 0s - loss: 0.2226 - accuracy: 0.9170 - val_loss: 0.2355 - val_accuracy: 0.9128
# Epoch 33/100
# 3579/3579 - 0s - loss: 0.2219 - accuracy: 0.9190 - val_loss: 0.2407 - val_accuracy: 0.9128
# Epoch 34/100
# 3579/3579 - 0s - loss: 0.2208 - accuracy: 0.9159 - val_loss: 0.2319 - val_accuracy: 0.9150
# Epoch 35/100
# 3579/3579 - 0s - loss: 0.2205 - accuracy: 0.9173 - val_loss: 0.2311 - val_accuracy: 0.9150
# Epoch 36/100
# 3579/3579 - 0s - loss: 0.2198 - accuracy: 0.9165 - val_loss: 0.2322 - val_accuracy: 0.9172
# Epoch 37/100
# 3579/3579 - 0s - loss: 0.2191 - accuracy: 0.9179 - val_loss: 0.2334 - val_accuracy: 0.9150
# Epoch 38/100
# 3579/3579 - 0s - loss: 0.2195 - accuracy: 0.9165 - val_loss: 0.2298 - val_accuracy: 0.9128
# Epoch 39/100
# 3579/3579 - 0s - loss: 0.2206 - accuracy: 0.9167 - val_loss: 0.2337 - val_accuracy: 0.9083
# Epoch 40/100
# 3579/3579 - 0s - loss: 0.2178 - accuracy: 0.9181 - val_loss: 0.2345 - val_accuracy: 0.9150
# Epoch 41/100
# 3579/3579 - 0s - loss: 0.2197 - accuracy: 0.9176 - val_loss: 0.2333 - val_accuracy: 0.9083
# Epoch 42/100
# 3579/3579 - 0s - loss: 0.2171 - accuracy: 0.9181 - val_loss: 0.2347 - val_accuracy: 0.9128
# Epoch 43/100
# 3579/3579 - 0s - loss: 0.2188 - accuracy: 0.9153 - val_loss: 0.2375 - val_accuracy: 0.9083
# Epoch 44/100
# 3579/3579 - 0s - loss: 0.2168 - accuracy: 0.9193 - val_loss: 0.2331 - val_accuracy: 0.9083
# Epoch 45/100
# 3579/3579 - 0s - loss: 0.2157 - accuracy: 0.9193 - val_loss: 0.2318 - val_accuracy: 0.9150
# Epoch 46/100
# 3579/3579 - 0s - loss: 0.2147 - accuracy: 0.9156 - val_loss: 0.2308 - val_accuracy: 0.9105
# Epoch 47/100
# 3579/3579 - 0s - loss: 0.2154 - accuracy: 0.9181 - val_loss: 0.2368 - val_accuracy: 0.9150
# Epoch 48/100
# 3579/3579 - 0s - loss: 0.2156 - accuracy: 0.9187 - val_loss: 0.2309 - val_accuracy: 0.9105
# Epoch 49/100
# 3579/3579 - 0s - loss: 0.2151 - accuracy: 0.9187 - val_loss: 0.2364 - val_accuracy: 0.9060
# Epoch 50/100
# 3579/3579 - 0s - loss: 0.2185 - accuracy: 0.9170 - val_loss: 0.2340 - val_accuracy: 0.9128
# Epoch 51/100
# 3579/3579 - 0s - loss: 0.2185 - accuracy: 0.9176 - val_loss: 0.2284 - val_accuracy: 0.9195
# Epoch 52/100
# 3579/3579 - 0s - loss: 0.2158 - accuracy: 0.9179 - val_loss: 0.2305 - val_accuracy: 0.9172
# Epoch 53/100
# 3579/3579 - 0s - loss: 0.2165 - accuracy: 0.9159 - val_loss: 0.2325 - val_accuracy: 0.9083
# Epoch 54/100
# 3579/3579 - 0s - loss: 0.2152 - accuracy: 0.9181 - val_loss: 0.2299 - val_accuracy: 0.9172
# Epoch 55/100
# 3579/3579 - 0s - loss: 0.2125 - accuracy: 0.9190 - val_loss: 0.2303 - val_accuracy: 0.9128
# Epoch 56/100
# 3579/3579 - 0s - loss: 0.2143 - accuracy: 0.9190 - val_loss: 0.2324 - val_accuracy: 0.9150
# Epoch 57/100
# 3579/3579 - 0s - loss: 0.2137 - accuracy: 0.9201 - val_loss: 0.2352 - val_accuracy: 0.9128
# Epoch 58/100
# 3579/3579 - 0s - loss: 0.2144 - accuracy: 0.9198 - val_loss: 0.2280 - val_accuracy: 0.9150
# Epoch 59/100
# 3579/3579 - 0s - loss: 0.2119 - accuracy: 0.9198 - val_loss: 0.2321 - val_accuracy: 0.9105
# Epoch 60/100
# 3579/3579 - 0s - loss: 0.2120 - accuracy: 0.9190 - val_loss: 0.2435 - val_accuracy: 0.9128
# Epoch 61/100
# 3579/3579 - 0s - loss: 0.2125 - accuracy: 0.9198 - val_loss: 0.2280 - val_accuracy: 0.9172
# Epoch 62/100
# 3579/3579 - 0s - loss: 0.2156 - accuracy: 0.9190 - val_loss: 0.2343 - val_accuracy: 0.9128
# Epoch 63/100
# 3579/3579 - 0s - loss: 0.2167 - accuracy: 0.9198 - val_loss: 0.2288 - val_accuracy: 0.9172
# Epoch 64/100
# 3579/3579 - 0s - loss: 0.2153 - accuracy: 0.9201 - val_loss: 0.2346 - val_accuracy: 0.9150
# Epoch 65/100
# 3579/3579 - 0s - loss: 0.2116 - accuracy: 0.9206 - val_loss: 0.2467 - val_accuracy: 0.9038
# Epoch 66/100
# 3579/3579 - 0s - loss: 0.2125 - accuracy: 0.9187 - val_loss: 0.2311 - val_accuracy: 0.9128
# Epoch 67/100
# 3579/3579 - 0s - loss: 0.2119 - accuracy: 0.9184 - val_loss: 0.2374 - val_accuracy: 0.9083
# Epoch 68/100
# 3579/3579 - 0s - loss: 0.2109 - accuracy: 0.9195 - val_loss: 0.2326 - val_accuracy: 0.9105
# Epoch 69/100
# 3579/3579 - 0s - loss: 0.2102 - accuracy: 0.9212 - val_loss: 0.2393 - val_accuracy: 0.9172
# Epoch 70/100
# 3579/3579 - 0s - loss: 0.2103 - accuracy: 0.9206 - val_loss: 0.2313 - val_accuracy: 0.9150
# Epoch 71/100
# 3579/3579 - 0s - loss: 0.2098 - accuracy: 0.9204 - val_loss: 0.2309 - val_accuracy: 0.9217
# Epoch 72/100
# 3579/3579 - 0s - loss: 0.2167 - accuracy: 0.9193 - val_loss: 0.2275 - val_accuracy: 0.9172
# Epoch 73/100
# 3579/3579 - 0s - loss: 0.2092 - accuracy: 0.9195 - val_loss: 0.2263 - val_accuracy: 0.9172
# Epoch 74/100
# 3579/3579 - 0s - loss: 0.2104 - accuracy: 0.9198 - val_loss: 0.2314 - val_accuracy: 0.9083
# Epoch 75/100
# 3579/3579 - 0s - loss: 0.2165 - accuracy: 0.9176 - val_loss: 0.2359 - val_accuracy: 0.9128
# Epoch 76/100
# 3579/3579 - 0s - loss: 0.2117 - accuracy: 0.9220 - val_loss: 0.2373 - val_accuracy: 0.9150
# Epoch 77/100
# 3579/3579 - 0s - loss: 0.2089 - accuracy: 0.9201 - val_loss: 0.2331 - val_accuracy: 0.9128
# Epoch 78/100
# 3579/3579 - 0s - loss: 0.2143 - accuracy: 0.9195 - val_loss: 0.2365 - val_accuracy: 0.9195
# Epoch 79/100
# 3579/3579 - 0s - loss: 0.2100 - accuracy: 0.9220 - val_loss: 0.2394 - val_accuracy: 0.9172
# Epoch 80/100
# 3579/3579 - 0s - loss: 0.2125 - accuracy: 0.9195 - val_loss: 0.2373 - val_accuracy: 0.9172
# Epoch 81/100
# 3579/3579 - 0s - loss: 0.2097 - accuracy: 0.9201 - val_loss: 0.2512 - val_accuracy: 0.9060
# Epoch 82/100
# 3579/3579 - 0s - loss: 0.2107 - accuracy: 0.9190 - val_loss: 0.2343 - val_accuracy: 0.9150
# Epoch 83/100
# 3579/3579 - 0s - loss: 0.2085 - accuracy: 0.9229 - val_loss: 0.2314 - val_accuracy: 0.9172
# Epoch 84/100
# 3579/3579 - 0s - loss: 0.2075 - accuracy: 0.9218 - val_loss: 0.2398 - val_accuracy: 0.9105
# Epoch 85/100
# 3579/3579 - 0s - loss: 0.2086 - accuracy: 0.9206 - val_loss: 0.2326 - val_accuracy: 0.9105
# Epoch 86/100
# 3579/3579 - 0s - loss: 0.2083 - accuracy: 0.9226 - val_loss: 0.2359 - val_accuracy: 0.9105
# Epoch 87/100
# 3579/3579 - 0s - loss: 0.2081 - accuracy: 0.9201 - val_loss: 0.2387 - val_accuracy: 0.9038
# Epoch 88/100
# 3579/3579 - 0s - loss: 0.2078 - accuracy: 0.9212 - val_loss: 0.2362 - val_accuracy: 0.9128
# Epoch 89/100
# 3579/3579 - 0s - loss: 0.2069 - accuracy: 0.9215 - val_loss: 0.2310 - val_accuracy: 0.9150
# Epoch 90/100
# 3579/3579 - 0s - loss: 0.2064 - accuracy: 0.9226 - val_loss: 0.2296 - val_accuracy: 0.9105
# Epoch 91/100
# 3579/3579 - 0s - loss: 0.2061 - accuracy: 0.9237 - val_loss: 0.2309 - val_accuracy: 0.9128
# Epoch 92/100
# 3579/3579 - 0s - loss: 0.2059 - accuracy: 0.9223 - val_loss: 0.2319 - val_accuracy: 0.9105
# Epoch 93/100
# 3579/3579 - 0s - loss: 0.2048 - accuracy: 0.9223 - val_loss: 0.2356 - val_accuracy: 0.9128
# Epoch 94/100
# 3579/3579 - 0s - loss: 0.2081 - accuracy: 0.9215 - val_loss: 0.2333 - val_accuracy: 0.9150
# Epoch 95/100
# 3579/3579 - 0s - loss: 0.2058 - accuracy: 0.9226 - val_loss: 0.2294 - val_accuracy: 0.9195
# Epoch 96/100
# 3579/3579 - 0s - loss: 0.2068 - accuracy: 0.9229 - val_loss: 0.2300 - val_accuracy: 0.9128
# Epoch 97/100
# 3579/3579 - 0s - loss: 0.2059 - accuracy: 0.9243 - val_loss: 0.2294 - val_accuracy: 0.9105
# Epoch 98/100
# 3579/3579 - 0s - loss: 0.2044 - accuracy: 0.9229 - val_loss: 0.2370 - val_accuracy: 0.9105
# Epoch 99/100
# 3579/3579 - 0s - loss: 0.2064 - accuracy: 0.9215 - val_loss: 0.2326 - val_accuracy: 0.9172
# Epoch 100/100
# 3579/3579 - 0s - loss: 0.2055 - accuracy: 0.9234 - val_loss: 0.2298 - val_accuracy: 0.9083
